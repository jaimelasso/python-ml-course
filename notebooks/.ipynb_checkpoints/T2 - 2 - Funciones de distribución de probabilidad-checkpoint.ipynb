# %% [markdown]
# # Funciones de distribución de probabilidades

# %% [markdown]
# ### 1. Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Para esta distribución debemos contar con un rango, en este caso a y b.
# A mayor cantidad de muestras (n) en el dataset, mayor será la cantidad de datos a distribuir uniformemente.
a = 1
b = 2
n = 10000000
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([1001479.,  998473., 1001942., 1000722.,  999861., 1000838.,
#          998959.,  998964.,  999149.,  999613.]),
#  array([1.00000005, 1.10000005, 1.20000004, 1.30000003, 1.40000002,
#         1.50000002, 1.60000001, 1.7       , 1.79999999, 1.89999999,
#         1.99999998]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribución Normal

# %%
# Generación de 100 números aleatorios que cumplen con la distribución normal.
data = np.random.randn(1000)
x = range(1,1001)
plt.plot(x, data)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([  3.,   7.,  45., 116., 234., 271., 190.,  94.,  35.,   5.]),
#  array([-3.73351371, -3.03593108, -2.33834845, -1.64076582, -0.94318319,
#         -0.24560056,  0.45198207,  1.14956469,  1.84714732,  2.54472995,
#          3.24231258]),
#  <a list of 10 Patch objects>)

# %%
# Frecuencias acumuladas ordenadas
plt.plot(x,sorted(data))

# %%
mean = 5.5 # Media
sd = 2.5 # Standard Deviation (Desviaciones estándar)
z_10000 = np.random.randn(10000)
data = mean + sd * z_10000 # z - (X - mu) / sd ---> N(0,1), X = mean + sd * z
plt.hist(data)
# Out:
# (array([2.000e+00, 1.140e+02, 5.150e+02, 1.724e+03, 2.852e+03, 2.723e+03,
#         1.531e+03, 4.510e+02, 8.200e+01, 6.000e+00]),
#  array([-4.11805184, -2.15393429, -0.18981674,  1.7743008 ,  3.73841835,
#          5.70253589,  7.66665344,  9.63077098, 11.59488853, 13.55900608,
#         15.52312362]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[-0.20043687, -0.98336973,  0.41438693,  0.52119509],
#        [ 0.06602266,  1.86399022, -0.28241695,  1.0670643 ]])

# %% [markdown]
# ## La simulación de Montecarlo

# %% [markdown]
# * Generamos dos números aleatorios uniforme x e y entre 0 y 1 en total 1000 veces.
# * Calcularemos $z = x^2 + y^2$:
#     * Si $z \lt 1 \rightarrow$ estamos dentro del círculo.
#     * Si $z \geq 1 \rightarrow$ estamos fuera del círculo.
# * Calculamos el número total de veces que están dentro del círculo y lo dividimos entre el número total de intentos para obtener una aproximación de la probabilidad de caer dentro del círculo.
# * Usamos dicha probabilidad para aproximar el valor de π.
# * Repetimos el experimento un número suficiente de veces (por ejemplo 100), para obtener (100) diferentes aproximaciones de π.
# * Calculamos el promedio de los 100 experimentos anteriores para dar un valor final de π.

# %%
def pi_montecarlo(n_points, n_exp):
    pi_avg = 0
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0, 1, n_points).tolist()
        y = np.random.uniform(0, 1, n_points).tolist()
        for j in range(n_points):
            z = np.sqrt(x[j] * x[j] + y[j] * y[j])
            if (z <= 1) :
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n_points
        pi_value_list.append(pi_value)
        pi_avg += pi_value
        
    pi = pi_avg / n_exp
    
    print(pi)
    fig = plt.plot(pi_value_list)
    return (pi, fig)

# %%
pi_montecarlo(10000,300)
# Out:
# 3.1429959999999992
# (3.1429959999999992, [<matplotlib.lines.Line2D at 0x22fe2d2cf48>])

# %% [markdown]
# ## Dummy Data Sets

# %%
n = 1000000
data = pd.DataFrame(
    {
        'Columna A' : np.random.randn(n),
        'Columna B' : 1.5 + 2.5 * np.random.randn(n),
        'Columna C' : np.random.uniform(5, 32, n)
    }
)

# %%
data.describe()
# Out:
#             Columna A       Columna B       Columna C
# count  1000000.000000  1000000.000000  1000000.000000
# mean         0.000430        1.502307       18.508318
# std          1.000226        2.499267        7.795722
# min         -5.615359      -10.611839        5.000000
# 25%         -0.674844       -0.185292       11.762889
# 50%          0.001338        1.506974       18.514081
# 75%          0.674257        3.190821       25.247114
# max          4.982426       13.655933       31.999988

# %%
plt.hist(data["Columna A"])
# Out:
# (array([4.00000e+00, 2.36000e+02, 7.05900e+03, 7.70570e+04, 2.91601e+05,
#         3.95447e+05, 1.92900e+05, 3.35480e+04, 2.11200e+03, 3.60000e+01]),
#  array([-5.61535892, -4.55558041, -3.49580189, -2.43602338, -1.37624487,
#         -0.31646635,  0.74331216,  1.80309067,  2.86286919,  3.9226477 ,
#          4.98242621]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["Columna B"])
# Out:
# (array([6.30000e+01, 1.75100e+03, 2.48270e+04, 1.41286e+05, 3.34530e+05,
#         3.33818e+05, 1.38254e+05, 2.37290e+04, 1.70200e+03, 4.00000e+01]),
#  array([-10.61183901,  -8.18506183,  -5.75828465,  -3.33150747,
#          -0.90473029,   1.52204689,   3.94882407,   6.37560125,
#           8.80237842,  11.2291556 ,  13.65593278]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data["Columna C"])
# Out:
# (array([100209.,  99408., 100104., 100232.,  99513.,  99860., 100343.,
#         100247.,  99656., 100428.]),
#  array([ 5.0000005 ,  7.6999992 , 10.39999791, 13.09999662, 15.79999532,
#         18.49999403, 21.19999274, 23.89999144, 26.59999015, 29.29998886,
#         31.99998757]),
#  <a list of 10 Patch objects>)

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
column_names = data.columns.values.tolist()
a = len(column_names)
print("Cantidad de columnas: " + str(a))
# Out:
# Cantidad de columnas: 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name': column_names,
        'A' : np.random.randn(),
        'B' : np.random.uniform(0, 1, a)
    }, index = range(42, 42 + a)
)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State -0.961149  0.221616
# 43  Account Length -0.961149  0.120782
# 44       Area Code -0.961149  0.504139
# 45           Phone -0.961149  0.629132
# 46      Int'l Plan -0.961149  0.424088
# 47      VMail Plan -0.961149  0.226998
# 48   VMail Message -0.961149  0.976468
# 49        Day Mins -0.961149  0.071586
# 50       Day Calls -0.961149  0.632608
# 51      Day Charge -0.961149  0.505152
# 52        Eve Mins -0.961149  0.618281
# 53       Eve Calls -0.961149  0.247511
# 54      Eve Charge -0.961149  0.393550
# 55      Night Mins -0.961149  0.275683
# 56     Night Calls -0.961149  0.125726
# 57    Night Charge -0.961149  0.328734
# 58       Intl Mins -0.961149  0.894505
# 59      Intl Calls -0.961149  0.688944
# 60     Intl Charge -0.961149  0.031647
# 61  CustServ Calls -0.961149  0.943627
# 62          Churn? -0.961149  0.659085
